# %% [markdown]
#   **Dataset information**
#
#   The data set contains 3 classes of 50 instaces each. Where each class refers to a type of iris plant.One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
#   Attribute information:
#
#   1.Sepal Legnth in cm
#
#   2.Sepal Width in cm
#
#   3.Petal Legnth in cm
#
#   4.Petal Witdh in cm
#
#   5.Class:--lris Setose--lrisVersicolor--lris Virginica

# %% [markdown]
# **import modules**

# %%
#importing all the essensial labraris for our project
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Loading the dataset**

# %%
df= pd.read_csv('iris_dataset.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
# to display stats about data
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#To basic info about datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#display number of samples on each class
df['target'].value_counts()
# Out:
# target
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Preprocessing the dataset**

# %%
#Check for null values
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Histogram
df['sepal length (cm)'].hist()
# Out:
# <Axes: >

# %%
df['sepal width (cm)'].hist()
# Out:
# <Axes: >

# %%
df[ 'petal length (cm)'].hist()
# Out:
# <Axes: >

# %%
df['petal width (cm)'].hist()
# Out:
# <Axes: >

# %%
# Scaterplots
colors = ['Red','Orange','Blue']
target = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
  x = df[df['target'] == target[i]]
  plt.scatter(x['sepal length (cm)'] , x['sepal width (cm)'] , c=colors[i], label=target[i])
  plt.xlabel("sepal length")
  plt.ylabel("sepal width")
  plt.legend()

# %%
for i in range(3):
  x = df[df['target'] == target[i]]
  plt.scatter(x['petal length (cm)'] , x['petal width (cm)'] , c=colors[i], label=target[i])
  plt.xlabel("petal length")
  plt.ylabel("petal width")
  plt.legend()

# %%
for i in range(3):
  x = df[df['target'] == target[i]]
  plt.scatter(x['sepal length (cm)'] , x['petal length (cm)'] , c=colors[i], label=target[i])
  plt.xlabel("sepal length")
  plt.ylabel("petal length")
  plt.legend()

# %%
for i in range(3):
  x = df[df['target'] == target[i]]
  plt.scatter(x['sepal width (cm)'] , x['petal width (cm)'] , c=colors[i], label=target[i])
  plt.xlabel("sepal width")
  plt.ylabel("petal width")
  plt.legend()
  plt.title('Scatter plot')

# %% [markdown]
# **Correlation Matrix**
#
# A correlation matrix is a table showing correlation codfficient between variables.Each cell in the table shows the correlation between two variables.The value is in the range of -1 to 1. If two variables have high correlation, we can negiect one variable from those two

# %%
# Coorelation Matrix
from sklearn.datasets import load_iris
df = pd.read_csv ('iris_dataset.csv')

# %%
df_numeric= df.select_dtypes(include = ['number'])
correlation_matrix = df_numeric.corr()
print(correlation_matrix)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.109369           0.871754
# sepal width (cm)           -0.109369          1.000000          -0.420516
# petal length (cm)           0.871754         -0.420516           1.000000
# petal width (cm)            0.817954         -0.356544           0.962757
#
#                    petal width (cm)
# sepal length (cm)          0.817954
# sepal width (cm)          -0.356544
# petal length (cm)          0.962757
# petal width (cm)           1.000000

# %%
df = pd.read_csv('iris_dataset.csv')
df_numeric = df.select_dtypes(include='number')
corr = df_numeric.corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True, cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# **Label Encoder**
#
# In machine learning. We usually deal with datasets which contains multiple labels in one or more than one columns. These labels can be in the form of eords of numbers. Label Encoder refers to converting the labels into numberic form so as to convert it into machine-readable form

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['target'] = le.fit_transform(df['target'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# **Model Training**

# %%
from sklearn.model_selection import train_test_split
# train -70
#test - 30
X = df.drop(columns=['target'])
Y = df['target']
x_train, x_test, y_train, y_test, = train_test_split(X,Y, test_size=0.30)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print metric to get performnce
print("Accuracy:",model.score(x_test, y_test)*100)
# Out:
# Accuracy: 97.77777777777777

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test)*100)
# Out:
# Accuracy:  97.77777777777777

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test)*100)
# Out:
# Accuracy:  97.77777777777777
